# %% [markdown]
# # **Density-based spatial clustering (DBSCAN)**
#
# DBSCAN documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html)

# %%
import numpy as np
from matplotlib import pyplot as plt
#import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
X, _ = make_blobs(n_samples = 1000, n_features = 2, random_state=69)

# Train test splits
X_train, X_test = train_test_split(X, test_size = 0.1, random_state=1)

_, axes = plt.subplots(1, 2, figsize = (8,4))
axes[0].scatter (X[:, 0], X[:, 1], c='b', edgecolors='k')
axes[1].scatter(X_train[:, 0], X_train[:, 1], c='b', edgecolors='k')
axes[1].scatter(X_test[:, 0], X_test[:, 1], c='r', edgecolors='k')
plt.show()

# %%
dbscan = DBSCAN(eps= 1 , min_samples= 5 )

#entre en 1 y 5 %

# Train DBSCAN

dbscan.fit(X_train)
# Out:
# DBSCAN(eps=1)

# %%
# Predictions
predictions = dbscan.fit_predict(X_test)
print(np.unique(predictions, return_counts=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-1397f12ccd43> in <cell line: 3>()
#       1 # Predictions
#       2 predictions = dbscan.fit_predict(X_test)
# ----> 3 print(np.unique(predictions, return_counts=True))
#
# TypeError: 'numpy.float64' object is not callable

# %%
_, ax = plt.subplots(figsize = (5,5))
_
ax.scatter( X_test[:, 0] , X_test[:, 1] , c=predictions, cmap='copper', edgecolors='k')

# %% [markdown]
# # **DBSCAN on real data**
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
_


plt.scatter( _ , _ )
print (X.shape, y.shape)

# %%
dbscan = DBSCAN(eps= _ , min_samples= _ )
dbscan.fit( _ )

# %%
predictions = _

# %%
# Plot
_

# %% [markdown]
# # **DBSCAN on images**
#
# Use any of the following images:
#  - [image1.jpeg](https://drive.google.com/file/d/1ehjQbNbSLTPOdnzZf5mtcokH-Irb9Hsq/view?usp=sharing)
#  - [image2.png](https://drive.google.com/file/d/1RxivIbgi2eAG6p1myuxQGJs2zhGEsH_4/view?usp=sharing)
#  - [image3.jpg](https://drive.google.com/file/d/1Pc_C9B_vqIxkLFV90RWSlRxRcTN-yKqF/view?usp=sharing)

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import DBSCAN
import cv2

# %%
#read imagen
original_image = cv2.imread('/content/image2.png')
original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
print(original_image.shape)

original_image = cv2.resize(original_image, (150, 100))
print(original_image.shape)

img_hsv = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)

_, ax = plt.subplots(figsize=(5,4))
ax.imshow(original_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-b07d6b3187b7> in <cell line: 4>()
#       2 original_image = cv2.imread('/content/image2.png')
#       3 original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
# ----> 4 print(original_image.shape)
#       5
#       6 original_image = cv2.resize(original_image, (150, 100))
#
# TypeError: 'numpy.float64' object is not callable

# %%
vectorized_hsv = img_hsv[:, :, 0].reshape(-1,1)
print(vectorized_hsv.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b35671e3052b> in <cell line: 2>()
#       1 vectorized_hsv = img_hsv[:, :, 0].reshape(-1,1)
# ----> 2 print(vectorized_hsv.shape)
#
# TypeError: 'numpy.float64' object is not callable

# %%
eps = abs(img_hsv[:, :, 0].min() - img_hsv[:, :, 0].max()) * 0.10
print (eps)
min_samples = int(len(vectorized_hsv)*0.6)
print(min_samples)
#dbscan = DBSCAN(eps)
# Out:
# <ipython-input-71-65d0ed6e60ad>:1: RuntimeWarning: overflow encountered in scalar subtract
#   eps = abs(img_hsv[:, :, 0].min() - img_hsv[:, :, 0].max()) * 0.10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-65d0ed6e60ad> in <cell line: 2>()
#       1 eps = abs(img_hsv[:, :, 0].min() - img_hsv[:, :, 0].max()) * 0.10
# ----> 2 print (eps)
#       3 min_samples = int(len(vectorized_hsv)*0.6)
#       4 print(min_samples)
#       5 #dbscan = DBSCAN(eps)
#
# TypeError: 'numpy.float64' object is not callable

# %%
dbscan = DBSCAN(eps= eps, min_samples = min_samples)
predictions = dbscan.fit_predict(vectorized_hsv)
print(predictions.shape)

# %%
print(np.unique(predictions))

# %%
predictions = predictions.reshape(original_image.shape[:2])

_, axes = plt.subplots(1, 2, figsize=(8,4))
axes[0].imshow
