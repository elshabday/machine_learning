# %% [markdown]
# # Let's start on the basics. Variables and arrays

# %% [markdown]
# ### First, import some libraries

# %%
import numpy as np

# %%
array_1 = np.array([5,9,3,1,4,5,8,7]) # Create an array of N values
array_2 = np.random.randint(1, 50, 8) # Create an array of random int values
            # with the same lenght as array_1

print (array_1,array_2)
print (array_1.shape,array_2.shape)
print (array_1 + array_2)
_ # print both array_1 and array_2
_ # print both array_1 and array_2 shapes
_ # print summation of array_1 and array_2
# Out:
# [5 9 3 1 4 5 8 7] [12 12 35 11 20 44  3 20]
# (8,) (8,)
# [17 21 38 12 24 49 11 27]
# ''

# %%
array_1[3]=70
print (array_1 + array_2)

_ # Replace the value of array_1 in pos 3 by 70
_ # Print summation again
# Out:
# [17 21 38 81 24 49 11 27]
# ''

# %%
array_3 = array_1 * array_2
print (array_3)
_ # Apply element-wise multiplication among array_1 and array_2
_ # Print results
# Out:
# [ 60 108 105 770  80 220  24 140]
# ''

# %%
for i in range(8):
  array_3[i] = array_1[i] * array_2[i]

print (array_3)
# Out:
# [ 60 108 105 770  80 220  24 140]

# %% [markdown]
# # Playing with some images! Introduction to OpenCV
#
# Download the image [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view) before getting started!

# %% [markdown]
# ### First, let's mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import some libraries

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load an image using OpenCV

# %%
# Loading a color image
img = cv2.imread('/content/drive/MyDrive/Ingenieria/04 Semestre/Machine Learning/machine_learning/Images/lena.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img) # plots an image

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (300, 400, 3)

# %% [markdown]
# ### Let's play with the data

# %%
# Printing the image shape (size of the image)
print (img.shape)
# Out:
# (300, 400, 3)

# %%
# Looking through the image...
# print among image indexes
print (img[0:10, 0:5, 0])
# Out:
# [[  0  21  15   7   0]
#  [ 18  91 102 106  95]
#  [ 15 107 122 114 104]
#  [  5 104 114 100  93]
#  [  0  88 104 104 103]
#  [ 11 107 120 124 127]
#  [ 12 110 116 110 113]
#  [  0 103 113 104 105]
#  [  0 118 120 103 113]
#  [  0 118 120 103 113]]

# %%
# Changing its channels values!
img = cv2.imread('/content/drive/MyDrive/Ingenieria/04 Semestre/Machine Learning/machine_learning/Images/lena.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[0:50, 0:50, 0:3] = 153

plt.imshow(img) # Voila!

# %%
lena_face = img[100:200, 180:270, 0:3]
plt.imshow(lena_face)

# %% [markdown]
# ### Load an image in grayscale

# %%
# Loading a color image in grayscale
img_gray = cv2.imread('/content/drive/MyDrive/Ingenieria/04 Semestre/Machine Learning/machine_learning/Images/lena.jpg', 0)
#img_gray = cv2.cvtColor(img_gray, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap = 'gray' )
print (img_gray.shape)
# Out:
# (300, 400)

# %% [markdown]
# ### Play with the image

# %%
# Printing the image shape
_

# %%
# Regarding through the image... Again

# %% [markdown]
# ### Going further

# %%
# Messing everything around.
img = cv2.imread( _ )
_
plt.imshow(img_gray, _ )

# %%
# Playing with image intensities
img_gray = cv2.imread( _ )

for r in _  :  # Go through rows
  for c in _ : # Go through cols
    if _ : # Create a simple condition
      _ # Do something

plt.imshow(img_gray, _ )

# %% [markdown]
# ### Save an image using OpenCV

# %%
cv2.imwrite('newlena.png',img_gray)

# %% [markdown]
# ### Crop the image - taking regions of interest (ROI)

# %%
# Extract some ROI
roi = _
plt.imshow(roi, _ )

# %%
img_gray[ _ , _ ] = roi
plt.imshow(img_gray, _ )

# %% [markdown]
# ## Load an image using pillow (PIL)

# %%
from PIL import Image

# %%
# Loading a color image
img = Image.open('/content/drive/MyDrive/Ingenieria/04 Semestre/Machine Learning/machine_learning/Images/lena.jpg')
plt.imshow(img) # plots an image

# %%
print (img[:10, :10]) ## Error. This is not an array

# %%
img = np.asarray( _ ) ## Convert to an array
print (img[ _ , _ ]) ## Now it works!
print (img.shape)

# %% [markdown]
# ### Load the image in grayscale

# %%
img = Image.open( _ ).convert("L")
plt.imshow(img, _ ) # plots an image
